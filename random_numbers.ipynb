# %%
import random
import numpy as np
import timeit

# %%
random.randint(-90,90)
# Out:
# -11

# %%
random.random()
# Out:
# 0.48629426893557337

# %%
random_number = random.randint(-90,89) + random.random()
random_number
# Out:
# -26.211854340021862

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
latitudes
# Out:
# [-42.21088678650202,
#  -56.09959153274706,
#  -28.54018714899467,
#  14.322057977706045,
#  -3.7327187764409806,
#  -47.04484785025727,
#  -89.02765845518864,
#  -49.27748724185444,
#  57.71978088802313,
#  -67.6883300507202]

# %%
random.randrange(-90, 90, step=1)
# Out:
# -34

# %%
random.randrange(-90, 90, step=3)
# Out:
# -84

# %%
random.uniform(-90, 90)
# Out:
# 81.75378340098834

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 43.31460518380541

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 12.7 µs ± 61.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.11 ms ± 7.39 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
